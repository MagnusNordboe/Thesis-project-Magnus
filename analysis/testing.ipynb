# %%
#On first run, this print works:
from convertcsv.get_all_metrics_with_tags import get_all_metrics_with_tags
from convertcsv.import_preprocess_v4 import readcsvs
import pandas as pd
from sklearn.impute import KNNImputer

file_list, y = get_all_metrics_with_tags(r"F:\Master\Kubernetes\sockshop\microservices-demo\query\automated\generated_csvs_4")
initial_readings = readcsvs(file_list, reduce_NaNs_treshold=False, remove_unique_cols=True, remove_monotonic_increasing=True)
print("hi")
# Out:
# hi

# %%
imputer = KNNImputer(n_neighbors=1)
complete_value_set = imputer.fit_transform(initial_readings)
imputed_df = pd.DataFrame(complete_value_set, index=initial_readings.index, columns=initial_readings.columns)

# %%
#Find the length of each individual time series
print("still works here")
import pandas as pd
arrays = [['A', 'A', 'B', 'B', 'C', 'C'],
          [1, 2, 1, 2, 1, 2]]
tuples = list(zip(*arrays))
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
data = {'value': [1, 2, 3, 4, 5, 6]}
df = pd.DataFrame(data, index=index)
print("before func")
def padding(df:pd.DataFrame):
    print("started funct")
    instances = df.index.get_level_values(0).unique()
    print("found instances")
    for instance in instances:
        print("instance for loop")
        #This line of code gets every second level index value that corresponds to vthe current first level index value. 
        second_level_values = df.index.get_level_values(1)[df.index.get_level_values(0)==instance]
        print("got the values together")
        length = len(second_level_values)
        print("got the length")
        print("{} length of values is: {}".format(instance, length))


padding(imputed_df)
# Out:
# still works here
# before func
# started funct
# found instances
# instance for loop
# got the values together
# got the length
# 0 length of values is: 133
# instance for loop
# got the values together
# got the length
# 1 length of values is: 133
# instance for loop
# got the values together
# got the length
# 2 length of values is: 133
# instance for loop
# got the values together
# got the length
# 3 length of values is: 133
# instance for loop
# got the values together
# got the length
# 4 length of values is: 126
# instance for loop
# got the values together
# got the length
# 5 length of values is: 133
# instance for loop
# got the values together
# got the length
# 6 length of values is: 133
# instance for loop
# got the values together
# got the length
# 7 length of values is: 133
# instance for loop
# got the values together
# got the length
# 8 length of values is: 133
# instance for loop
# got the values together
# got the length
# 9 length of values is: 133
# instance for loop
# got the values together
# got the length
# 10 length of values is: 133
# instance for loop
# got the values together
# got the length
# 11 length of values is: 133
# instance for loop
# got the values together
# got the length
# 12 length of values is: 133
# instance for loop
# got the values together
# got the length
# 13 length of values is: 133
# instance for loop
# got the values together
# got the length
# 14 length of values is: 133
# instance for loop
# got the values together
# got the length
# 15 length of values is: 133
# instance for loop
# got the values together
# got the length
# 16 length of values is: 133
# instance for loop
# got the values together
# got the length
# 17 length of values is: 133
# instance for loop
# got the values together
# got the length
# 18 length of values is: 133
# instance for loop
# got the values together
# got the length
# 19 length of values is: 126
# instance for loop
# got the values together
# got the length
# 20 length of values is: 133
# instance for loop
# got the values together
# got the length
# 21 length of values is: 133
# instance for loop
# got the values together
# got the length
# 22 length of values is: 133
# instance for loop
# got the values together
# got the length
# 23 length of values is: 133
# instance for loop
# got the values together
# got the length
# 24 length of values is: 133
# instance for loop
# got the values together
# got the length
# 25 length of values is: 133
# instance for loop
# got the values together
# got the length
# 26 length of values is: 133
# instance for loop
# got the values together
# got the length
# 27 length of values is: 133
# instance for loop
# got the values together
# got the length
# 28 length of values is: 133
# instance for loop
# got the values together
# got the length
# 29 length of values is: 133
# instance for loop
# got the values together
# got the length
# 30 length of values is: 133
# instance for loop
# got the values together
# got the length
# 31 length of values is: 133
# instance for loop
# got the values together
# got the length
# 32 length of values is: 133
# instance for loop
# got the values together
# got the length
# 33 length of values is: 133
# instance for loop
# got the values together
# got the length
# 34 length of values is: 126
# instance for loop
# got the values together
# got the length
# 35 length of values is: 133
# instance for loop
# got the values together
# got the length
# 36 length of values is: 133
# instance for loop
# got the values together
# got the length
# 37 length of values is: 133
# instance for loop
# got the values together
# got the length
# 38 length of values is: 133
# instance for loop
# got the values together
# got the length
# 39 length of values is: 133
# instance for loop
# got the values together
# got the length
# 40 length of values is: 133
# instance for loop
# got the values together
# got the length
# 41 length of values is: 133
# instance for loop
# got the values together
# got the length
# 42 length of values is: 133
# instance for loop
# got the values together
# got the length
# 43 length of values is: 133
# instance for loop
# got the values together
# got the length
# 44 length of values is: 133
# instance for loop
# got the values together
# got the length
# 45 length of values is: 133
# instance for loop
# got the values together
# got the length
# 46 length of values is: 133
# instance for loop
# got the values together
# got the length
# 47 length of values is: 133
# instance for loop
# got the values together
# got the length
# 48 length of values is: 133
# instance for loop
# got the values together
# got the length
# 49 length of values is: 133
# instance for loop
# got the values together
# got the length
# 50 length of values is: 133
# instance for loop
# got the values together
# got the length
# 51 length of values is: 126
# instance for loop
# got the values together
# got the length
# 52 length of values is: 133
# instance for loop
# got the values together
# got the length
# 53 length of values is: 133
# instance for loop
# got the values together
# got the length
# 54 length of values is: 133
# instance for loop
# got the values together
# got the length
# 55 length of values is: 133
# instance for loop
# got the values together
# got the length
# 56 length of values is: 133
# instance for loop
# got the values together
# got the length
# 57 length of values is: 133
# instance for loop
# got the values together
# got the length
# 58 length of values is: 133
# instance for loop
# got the values together
# got the length
# 59 length of values is: 133
# instance for loop
# got the values together
# got the length
# 60 length of values is: 133
# instance for loop
# got the values together
# got the length
# 61 length of values is: 133
# instance for loop
# got the values together
# got the length
# 62 length of values is: 133
# instance for loop
# got the values together
# got the length
# 63 length of values is: 133
# instance for loop
# got the values together
# got the length
# 64 length of values is: 133
# instance for loop
# got the values together
# got the length
# 65 length of values is: 126
# instance for loop
# got the values together
# got the length
# 66 length of values is: 133
# instance for loop
# got the values together
# got the length
# 67 length of values is: 133
# instance for loop
# got the values together
# got the length
# 68 length of values is: 133
# instance for loop
# got the values together
# got the length
# 69 length of values is: 133
# instance for loop
# got the values together
# got the length
# 70 length of values is: 133
# instance for loop
# got the values together
# got the length
# 71 length of values is: 133
# instance for loop
# got the values together
# got the length
# 72 length of values is: 133
# instance for loop
# got the values together
# got the length
# 73 length of values is: 133
# instance for loop
# got the values together
# got the length
# 74 length of values is: 133
# instance for loop
# got the values together
# got the length
# 75 length of values is: 133
